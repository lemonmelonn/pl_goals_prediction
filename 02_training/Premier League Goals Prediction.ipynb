# %% [markdown]
# # GOAL PREDICTION ALGORITHM

# %% [markdown]
# ### Import Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit 
import pickle

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant
from statsmodels.api import OLS, add_constant
from sklearn.feature_selection import RFE
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import *
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("PL Teams 2022--23 Dataset.csv")

# %% [markdown]
# ### Data Inspection

# %%
df.describe()
# Out:
#        table_position    matchday  total_shots  shots_on_target       goals  \
# count      760.000000  760.000000   760.000000       760.000000  760.000000
# mean        10.500000   19.500000    10.338158         4.182895    1.443421
# std          5.770079   10.973078     5.064289         2.195809    1.336410
# min          1.000000    1.000000     1.000000         0.000000    0.000000
# 25%          5.750000   10.000000     7.000000         3.000000    0.000000
# 50%         10.500000   19.500000    10.000000         4.000000    1.000000
# 75%         15.250000   29.000000    13.000000         5.000000    2.000000
# max         20.000000   38.000000    31.000000        12.000000    9.000000
#
#         possesion   duels_won
# count  760.000000  760.000000
# mean     0.499697    0.500842
# std      0.127814    0.050443
# min      0.180000    0.350000
# 25%      0.400000    0.470000
# 50%      0.500000    0.500000
# 75%      0.590000    0.530000
# max      0.820000    0.650000

# %%
def inspection(df):
    print(f'Data Shape=: {df.shape}')
    summ = pd.DataFrame(df.dtypes, columns=['Data Types'])
    summ['Missing Values'] = df.isna().sum()
    summ['Missing Percentage'] = (df.isna().sum())/len(df)*100
    summ['Duplicates'] = df.duplicated().sum()
    summ['Unique'] = df.nunique().values
    summ['Count'] = df.count().values

    display(summ)
    
inspection(df)
# Out:
# Data Shape=: (760, 8)
#                 Data Types  Missing Values  Missing Percentage  Duplicates  \
# table_position       int64               0                 0.0           0
# team_name           object               0                 0.0           0
# matchday             int64               0                 0.0           0
# total_shots          int64               0                 0.0           0
# shots_on_target      int64               0                 0.0           0
# goals                int64               0                 0.0           0
# possesion          float64               0                 0.0           0
# duels_won          float64               0                 0.0           0
#
#                  Unique  Count
# table_position       20    760
# team_name            20    760
# matchday             38    760
# total_shots          31    760
# shots_on_target      13    760
# goals                 9    760
# possesion            61    760
# duels_won            31    760

# %% [markdown]
# From this output, we know that there are no missing or duplicated values in any columns. The dataset is properly formatted and ready for analysis.

# %% [markdown]
# ### Correlation Heatmap

# %%
numeric_data = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Set up the matplotlib figure
plt.figure(figsize=(18, 12))

# Draw the heatmap
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt='.2f', linewidths=0.5)

# Title and labels
plt.title('Correlation Heatmap of Dataset Features', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Our target variable is "goals". From the heatmap, we can observe that the feature with the highest correlation is "shots on target".

# %%
# Group by 'team' and sum the goals
team_goals = df.groupby('team_name')['goals'].sum().sort_values(ascending=False)

# Print the result
print(team_goals)
# Out:
# team_name
# Manchester City            95
# Arsenal                    88
# Liverpool                  75
# Brighton & Hove Albion     72
# Tottenham Hotspur          70
# Newcastle United           68
# Brentford                  58
# Manchester United          58
# Fulham                     55
# Aston Villa                51
# Leicester                  51
# Leeds United               48
# West Ham United            42
# Crystal Palace             40
# Chelsea                    38
# Nottingham Forest          38
# Bournemouth                37
# Southampton                36
# Everton                    34
# Wolverhampton Wanderers    31
# Name: goals, dtype: int64

# %%
# Group by 'team' and sum the shots on target
team_shots = df.groupby('team_name')['shots_on_target'].sum().sort_values(ascending=False)

# Print the result
print(team_shots)
# Out:
# team_name
# Arsenal                    212
# Brighton & Hove Albion     193
# Tottenham Hotspur          183
# Newcastle United           173
# Manchester United          170
# Leicester                  169
# Brentford                  159
# Liverpool                  158
# Fulham                     156
# Leeds United               155
# Chelsea                    155
# Manchester City            154
# Everton                    153
# Nottingham Forest          147
# Bournemouth                147
# West Ham United            147
# Wolverhampton Wanderers    143
# Aston Villa                136
# Crystal Palace             135
# Southampton                134
# Name: shots_on_target, dtype: int64

# %%
# Group by team and calculate total shots and total goals
team_stats = df.groupby('team_name').agg({'shots_on_target': 'sum', 'goals': 'sum'})

# Compute shots per goal (avoid division by zero)
team_stats['shots_per_goal'] = team_stats['shots_on_target'] / team_stats['goals']
team_stats['shots_per_goal'].replace([np.inf, np.nan], 0, inplace=True)  # Handle division by zero

# Sort in ascending order (lower shots per goal is better)
team_stats = team_stats.sort_values(by='shots_per_goal', ascending=True)

# Print result
print(team_stats)
# Out:
#                          shots_on_target  goals  shots_per_goal
# team_name
# Manchester City                      154     95        1.621053
# Liverpool                            158     75        2.106667
# Arsenal                              212     95        2.231579
# Newcastle United                     173     70        2.471429
# Tottenham Hotspur                    183     70        2.614286
# Aston Villa                          136     51        2.666667
# Brighton & Hove Albion               193     72        2.680556
# Brentford                            159     58        2.741379
# Fulham                               156     55        2.836364
# Manchester United                    170     58        2.931034
# Leeds United                         155     48        3.229167
# Leicester                            169     51        3.313725
# Crystal Palace                       135     40        3.375000
# West Ham United                      147     42        3.500000
# Southampton                          134     36        3.722222
# Chelsea                              155     41        3.780488
# Nottingham Forest                    147     38        3.868421
# Bournemouth                          147     37        3.972973
# Everton                              153     34        4.500000
# Wolverhampton Wanderers              143     31        4.612903
# C:\Users\User\AppData\Local\Temp\ipykernel_85120\3946429521.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   team_stats['shots_per_goal'].replace([np.inf, np.nan], 0, inplace=True)  # Handle division by zero

# %% [markdown]
# ### Custom Algorithm

# %% [markdown]
# For this situation, we will use custom calculations instead of a fixed model. The algorithm captures the team name and views it's respective records. Then, it filters values according to the similar number of shots on target. The average number of goals is calculated based on these records.

# %%
def predict_goals(team_name, shots_input):
    # Filter data only for the selected team
    team_data = df[df['team_name'] == team_name]
    
    # Handle case where the team has no past data
    if team_data.empty:
        print("No data available for this team.")
        return None

    # Find records where the team had similar shots on target
    matching_records = team_data[
        (team_data['shots_on_target'] >= shots_input - 1) &
        (team_data['shots_on_target'] <= shots_input + 1)
    ]

    if matching_records.empty:
        print(f"No past matches where {team_name} had {shots_input} shots on target.")
        return None

    # Calculate average goals scored in similar matches
    predicted_goals = matching_records['goals'].mean()

    print(f"xG for {team_name} with {shots_input} shots on target: {predicted_goals}")
    return predicted_goals

# %%
# USER INPUT & PREDICTION
user_team = input("Enter team name: ")
user_shots = int(input("Enter shots on target: "))

# Predict using custom function
predict_goals(user_team, user_shots)
# Out:
# Enter team name:  Chelsea
# Enter shots on target:  4
# xG for Chelsea with 4 shots on target: 1.0
# 1.0

# %%
# Calculating number of predicted goals for each row, and adding them into the dataset
df['predicted_goals'] = df.apply(lambda row: predict_goals(row['team_name'], row['shots_on_target']), axis=1)
# Out:
# xG for Manchester City with 3 shots on target: 1.4444444444444444
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 4 shots on target: 2.576923076923077
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 8 shots on target: 5.333333333333333
# xG for Manchester City with 3 shots on target: 1.4444444444444444
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 8 shots on target: 5.333333333333333
# xG for Manchester City with 6 shots on target: 3.5625
# xG for Manchester City with 2 shots on target: 1.0666666666666667
# xG for Manchester City with 4 shots on target: 2.576923076923077
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 3 shots on target: 1.4444444444444444
# xG for Manchester City with 4 shots on target: 2.576923076923077
# xG for Manchester City with 2 shots on target: 1.0666666666666667
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 3 shots on target: 1.4444444444444444
# xG for Manchester City with 3 shots on target: 1.4444444444444444
# xG for Manchester City with 2 shots on target: 1.0666666666666667
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 0 shots on target: 0.0
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 3 shots on target: 1.4444444444444444
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 3 shots on target: 1.4444444444444444
# xG for Manchester City with 2 shots on target: 1.0666666666666667
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 6 shots on target: 3.5625
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 3 shots on target: 1.4444444444444444
# xG for Manchester City with 7 shots on target: 4.8
# xG for Manchester City with 3 shots on target: 1.4444444444444444
# xG for Manchester City with 4 shots on target: 2.576923076923077
# xG for Manchester City with 5 shots on target: 3.3157894736842106
# xG for Manchester City with 2 shots on target: 1.0666666666666667
# xG for Manchester City with 1 shots on target: 0.5714285714285714
# xG for Arsenal with 4 shots on target: 1.3125
# xG for Arsenal with 7 shots on target: 3.6
# xG for Arsenal with 6 shots on target: 3.066666666666667
# xG for Arsenal with 8 shots on target: 3.8125
# xG for Arsenal with 9 shots on target: 4.375
# xG for Arsenal with 3 shots on target: 0.9333333333333333
# xG for Arsenal with 7 shots on target: 3.6
# xG for Arsenal with 7 shots on target: 3.6
# xG for Arsenal with 9 shots on target: 4.375
# xG for Arsenal with 7 shots on target: 3.6
# xG for Arsenal with 3 shots on target: 0.9333333333333333
# xG for Arsenal with 4 shots on target: 1.3125
# xG for Arsenal with 3 shots on target: 0.9333333333333333
# xG for Arsenal with 10 shots on target: 4.5
# xG for Arsenal with 2 shots on target: 0.6666666666666666
# xG for Arsenal with 4 shots on target: 1.3125
# xG for Arsenal with 7 shots on target: 3.6
# xG for Arsenal with 7 shots on target: 3.6
# xG for Arsenal with 4 shots on target: 1.3125
# xG for Arsenal with 5 shots on target: 1.9166666666666667
# xG for Arsenal with 5 shots on target: 1.9166666666666667
# xG for Arsenal with 3 shots on target: 0.9333333333333333
# xG for Arsenal with 4 shots on target: 1.3125
# xG for Arsenal with 8 shots on target: 3.8125
# xG for Arsenal with 3 shots on target: 0.9333333333333333
# xG for Arsenal with 9 shots on target: 4.375
# xG for Arsenal with 7 shots on target: 3.6
# xG for Arsenal with 8 shots on target: 3.8125
# xG for Arsenal with 7 shots on target: 3.6
# xG for Arsenal with 5 shots on target: 1.9166666666666667
# xG for Arsenal with 5 shots on target: 1.9166666666666667
# xG for Arsenal with 6 shots on target: 3.066666666666667
# xG for Arsenal with 2 shots on target: 0.6666666666666666
# xG for Arsenal with 7 shots on target: 3.6
# xG for Arsenal with 4 shots on target: 1.3125
# xG for Arsenal with 2 shots on target: 0.6666666666666666
# xG for Arsenal with 3 shots on target: 0.9333333333333333
# xG for Arsenal with 8 shots on target: 3.8125
# xG for Manchester United with 4 shots on target: 1.4
# xG for Manchester United with 3 shots on target: 0.85
# xG for Manchester United with 5 shots on target: 1.7142857142857142
# xG for Manchester United with 4 shots on target: 1.4
# xG for Manchester United with 3 shots on target: 0.85
# xG for Manchester United with 7 shots on target: 2.7142857142857144
# xG for Manchester United with 4 shots on target: 1.4
# xG for Manchester United with 6 shots on target: 2.2142857142857144
# xG for Manchester United with 7 shots on target: 2.7142857142857144
# xG for Manchester United with 4 shots on target: 1.4
# xG for Manchester United with 2 shots on target: 0.36363636363636365
# xG for Manchester United with 5 shots on target: 1.7142857142857142
# xG for Manchester United with 4 shots on target: 1.4
# xG for Manchester United with 3 shots on target: 0.85
# xG for Manchester United with 3 shots on target: 0.85
# xG for Manchester United with 7 shots on target: 2.7142857142857144
# xG for Manchester United with 8 shots on target: 3.0
# xG for Manchester United with 4 shots on target: 1.4
# xG for Manchester United with 6 shots on target: 2.2142857142857144
# xG for Manchester United with 4 shots on target: 1.4
# xG for Manchester United with 4 shots on target: 1.4
# xG for Manchester United with 5 shots on target: 1.7142857142857142
# xG for Manchester United with 5 shots on target: 1.7142857142857142
# xG for Manchester United with 8 shots on target: 3.0
# xG for Manchester United with 3 shots on target: 0.85
# xG for Manchester United with 2 shots on target: 0.36363636363636365
# xG for Manchester United with 2 shots on target: 0.36363636363636365
# xG for Manchester United with 3 shots on target: 0.85
# xG for Manchester United with 1 shots on target: 0.0
# xG for Manchester United with 5 shots on target: 1.7142857142857142
# xG for Manchester United with 5 shots on target: 1.7142857142857142
# xG for Manchester United with 9 shots on target: 3.3333333333333335
# xG for Manchester United with 5 shots on target: 1.7142857142857142
# xG for Manchester United with 4 shots on target: 1.4
# xG for Manchester United with 2 shots on target: 0.36363636363636365
# xG for Manchester United with 5 shots on target: 1.7142857142857142
# xG for Manchester United with 4 shots on target: 1.4
# xG for Manchester United with 5 shots on target: 1.7142857142857142
# xG for Newcastle United with 5 shots on target: 1.7857142857142858
# xG for Newcastle United with 1 shots on target: 0.18181818181818182
# xG for Newcastle United with 6 shots on target: 2.4
# xG for Newcastle United with 4 shots on target: 1.5294117647058822
# xG for Newcastle United with 3 shots on target: 0.7368421052631579
# xG for Newcastle United with 2 shots on target: 0.4
# xG for Newcastle United with 9 shots on target: 4.333333333333333
# xG for Newcastle United with 3 shots on target: 0.7368421052631579
# xG for Newcastle United with 8 shots on target: 4.125
# xG for Newcastle United with 9 shots on target: 4.333333333333333
# xG for Newcastle United with 2 shots on target: 0.4
# xG for Newcastle United with 4 shots on target: 1.5294117647058822
# xG for Newcastle United with 5 shots on target: 1.7857142857142858
# xG for Newcastle United with 7 shots on target: 3.6666666666666665
# xG for Newcastle United with 8 shots on target: 4.125
# xG for Newcastle United with 3 shots on target: 0.7368421052631579
# xG for Newcastle United with 7 shots on target: 3.6666666666666665
# xG for Newcastle United with 2 shots on target: 0.4
# xG for Newcastle United with 2 shots on target: 0.4
# xG for Newcastle United with 4 shots on target: 1.5294117647058822
# xG for Newcastle United with 1 shots on target: 0.18181818181818182
# xG for Newcastle United with 2 shots on target: 0.4
# xG for Newcastle United with 3 shots on target: 0.7368421052631579
# xG for Newcastle United with 2 shots on target: 0.4
# xG for Newcastle United with 9 shots on target: 4.333333333333333
# xG for Newcastle United with 2 shots on target: 0.4
# xG for Newcastle United with 5 shots on target: 1.7857142857142858
# xG for Newcastle United with 4 shots on target: 1.5294117647058822
# xG for Newcastle United with 5 shots on target: 1.7857142857142858
# xG for Newcastle United with 4 shots on target: 1.5294117647058822
# xG for Newcastle United with 2 shots on target: 0.4
# xG for Newcastle United with 11 shots on target: 6.0
# xG for Newcastle United with 8 shots on target: 4.125
# xG for Newcastle United with 5 shots on target: 1.7857142857142858
# xG for Newcastle United with 5 shots on target: 1.7857142857142858
# xG for Newcastle United with 5 shots on target: 1.7857142857142858
# xG for Newcastle United with 4 shots on target: 1.5294117647058822
# xG for Newcastle United with 2 shots on target: 0.4
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 12 shots on target: 7.5
# xG for Liverpool with 5 shots on target: 2.5
# xG for Liverpool with 2 shots on target: 0.7
# xG for Liverpool with 4 shots on target: 1.6956521739130435
# xG for Liverpool with 2 shots on target: 0.7
# xG for Liverpool with 6 shots on target: 2.7142857142857144
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 2 shots on target: 0.7
# xG for Liverpool with 2 shots on target: 0.7
# xG for Liverpool with 4 shots on target: 1.6956521739130435
# xG for Liverpool with 5 shots on target: 2.5
# xG for Liverpool with 6 shots on target: 2.7142857142857144
# xG for Liverpool with 5 shots on target: 2.5
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 2 shots on target: 0.7
# xG for Liverpool with 1 shots on target: 0.125
# xG for Liverpool with 2 shots on target: 0.7
# xG for Liverpool with 4 shots on target: 1.6956521739130435
# xG for Liverpool with 4 shots on target: 1.6956521739130435
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 10 shots on target: 6.5
# xG for Liverpool with 2 shots on target: 0.7
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 4 shots on target: 1.6956521739130435
# xG for Liverpool with 11 shots on target: 7.333333333333333
# xG for Liverpool with 6 shots on target: 2.7142857142857144
# xG for Liverpool with 4 shots on target: 1.6956521739130435
# xG for Liverpool with 4 shots on target: 1.6956521739130435
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 5 shots on target: 2.5
# xG for Liverpool with 3 shots on target: 1.1538461538461537
# xG for Liverpool with 8 shots on target: 4.0
# xG for Brighton & Hove Albion with 5 shots on target: 1.5
# xG for Brighton & Hove Albion with 3 shots on target: 0.8947368421052632
# xG for Brighton & Hove Albion with 5 shots on target: 1.5
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Brighton & Hove Albion with 11 shots on target: 5.5
# xG for Brighton & Hove Albion with 5 shots on target: 1.5
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Brighton & Hove Albion with 7 shots on target: 3.125
# xG for Brighton & Hove Albion with 2 shots on target: 0.4444444444444444
# xG for Brighton & Hove Albion with 1 shots on target: 0.25
# xG for Brighton & Hove Albion with 2 shots on target: 0.4444444444444444
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Brighton & Hove Albion with 9 shots on target: 3.75
# xG for Brighton & Hove Albion with 8 shots on target: 3.3333333333333335
# xG for Brighton & Hove Albion with 3 shots on target: 0.8947368421052632
# xG for Brighton & Hove Albion with 7 shots on target: 3.125
# xG for Brighton & Hove Albion with 5 shots on target: 1.5
# xG for Brighton & Hove Albion with 8 shots on target: 3.3333333333333335
# xG for Brighton & Hove Albion with 7 shots on target: 3.125
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Brighton & Hove Albion with 3 shots on target: 0.8947368421052632
# xG for Brighton & Hove Albion with 3 shots on target: 0.8947368421052632
# xG for Brighton & Hove Albion with 3 shots on target: 0.8947368421052632
# xG for Brighton & Hove Albion with 2 shots on target: 0.4444444444444444
# xG for Brighton & Hove Albion with 9 shots on target: 3.75
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Brighton & Hove Albion with 7 shots on target: 3.125
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Brighton & Hove Albion with 5 shots on target: 1.5
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Brighton & Hove Albion with 5 shots on target: 1.5
# xG for Brighton & Hove Albion with 11 shots on target: 5.5
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Brighton & Hove Albion with 6 shots on target: 2.4166666666666665
# xG for Brighton & Hove Albion with 7 shots on target: 3.125
# xG for Brighton & Hove Albion with 4 shots on target: 1.2272727272727273
# xG for Aston Villa with 2 shots on target: 0.6666666666666666
# xG for Aston Villa with 4 shots on target: 1.48
# xG for Aston Villa with 5 shots on target: 1.8823529411764706
# xG for Aston Villa with 3 shots on target: 1.0869565217391304
# xG for Aston Villa with 3 shots on target: 1.0869565217391304
# xG for Aston Villa with 1 shots on target: 0.4
# xG for Aston Villa with 5 shots on target: 1.8823529411764706
# xG for Aston Villa with 3 shots on target: 1.0869565217391304
# xG for Aston Villa with 2 shots on target: 0.6666666666666666
# xG for Aston Villa with 2 shots on target: 0.6666666666666666
# xG for Aston Villa with 1 shots on target: 0.4
# xG for Aston Villa with 2 shots on target: 0.6666666666666666
# xG for Aston Villa with 9 shots on target: 4.0
# xG for Aston Villa with 0 shots on target: 0.25
# xG for Aston Villa with 5 shots on target: 1.8823529411764706
# xG for Aston Villa with 4 shots on target: 1.48
# xG for Aston Villa with 3 shots on target: 1.0869565217391304
# xG for Aston Villa with 4 shots on target: 1.48
# xG for Aston Villa with 4 shots on target: 1.48
# xG for Aston Villa with 5 shots on target: 1.8823529411764706
# xG for Aston Villa with 5 shots on target: 1.8823529411764706
# xG for Aston Villa with 4 shots on target: 1.48
# xG for Aston Villa with 2 shots on target: 0.6666666666666666
# xG for Aston Villa with 5 shots on target: 1.8823529411764706
# xG for Aston Villa with 5 shots on target: 1.8823529411764706
# xG for Aston Villa with 3 shots on target: 1.0869565217391304
# xG for Aston Villa with 4 shots on target: 1.48
# xG for Aston Villa with 7 shots on target: 3.0
# xG for Aston Villa with 4 shots on target: 1.48
# xG for Aston Villa with 3 shots on target: 1.0869565217391304
# xG for Aston Villa with 6 shots on target: 2.1
# xG for Aston Villa with 2 shots on target: 0.6666666666666666
# xG for Aston Villa with 3 shots on target: 1.0869565217391304
# xG for Aston Villa with 1 shots on target: 0.4
# xG for Aston Villa with 3 shots on target: 1.0869565217391304
# xG for Aston Villa with 4 shots on target: 1.48
# xG for Aston Villa with 3 shots on target: 1.0869565217391304
# xG for Aston Villa with 5 shots on target: 1.8823529411764706
# xG for Tottenham Hotspur with 8 shots on target: 3.5
# xG for Tottenham Hotspur with 5 shots on target: 1.6875
# xG for Tottenham Hotspur with 4 shots on target: 1.2727272727272727
# xG for Tottenham Hotspur with 6 shots on target: 2.4375
# xG for Tottenham Hotspur with 4 shots on target: 1.2727272727272727
# xG for Tottenham Hotspur with 5 shots on target: 1.6875
# xG for Tottenham Hotspur with 5 shots on target: 1.6875
# xG for Tottenham Hotspur with 10 shots on target: 6.0
# xG for Tottenham Hotspur with 3 shots on target: 0.8235294117647058
# xG for Tottenham Hotspur with 3 shots on target: 0.8235294117647058
# xG for Tottenham Hotspur with 5 shots on target: 1.6875
# xG for Tottenham Hotspur with 2 shots on target: 0.6923076923076923
# xG for Tottenham Hotspur with 4 shots on target: 1.2727272727272727
# xG for Tottenham Hotspur with 7 shots on target: 3.0
# xG for Tottenham Hotspur with 3 shots on target: 0.8235294117647058
# xG for Tottenham Hotspur with 8 shots on target: 3.5
# xG for Tottenham Hotspur with 6 shots on target: 2.4375
# xG for Tottenham Hotspur with 2 shots on target: 0.6923076923076923
# xG for Tottenham Hotspur with 7 shots on target: 3.0
# xG for Tottenham Hotspur with 3 shots on target: 0.8235294117647058
# xG for Tottenham Hotspur with 3 shots on target: 0.8235294117647058
# xG for Tottenham Hotspur with 3 shots on target: 0.8235294117647058
# xG for Tottenham Hotspur with 4 shots on target: 1.2727272727272727
# xG for Tottenham Hotspur with 6 shots on target: 2.4375
# xG for Tottenham Hotspur with 5 shots on target: 1.6875
# xG for Tottenham Hotspur with 1 shots on target: 0.0
# xG for Tottenham Hotspur with 7 shots on target: 3.0
# xG for Tottenham Hotspur with 8 shots on target: 3.5
# xG for Tottenham Hotspur with 3 shots on target: 0.8235294117647058
# xG for Tottenham Hotspur with 5 shots on target: 1.6875
# xG for Tottenham Hotspur with 5 shots on target: 1.6875
# xG for Tottenham Hotspur with 3 shots on target: 0.8235294117647058
# xG for Tottenham Hotspur with 6 shots on target: 2.4375
# xG for Tottenham Hotspur with 7 shots on target: 3.0
# xG for Tottenham Hotspur with 3 shots on target: 0.8235294117647058
# xG for Tottenham Hotspur with 3 shots on target: 0.8235294117647058
# xG for Tottenham Hotspur with 4 shots on target: 1.2727272727272727
# xG for Tottenham Hotspur with 7 shots on target: 3.0
# xG for Brentford with 5 shots on target: 1.8333333333333333
# xG for Brentford with 7 shots on target: 3.0
# xG for Brentford with 5 shots on target: 1.8333333333333333
# xG for Brentford with 4 shots on target: 1.4166666666666667
# xG for Brentford with 3 shots on target: 0.95
# xG for Brentford with 9 shots on target: 4.0
# xG for Brentford with 5 shots on target: 1.8333333333333333
# xG for Brentford with 2 shots on target: 0.4666666666666667
# xG for Brentford with 2 shots on target: 0.4666666666666667
# xG for Brentford with 3 shots on target: 0.95
# xG for Brentford with 4 shots on target: 1.4166666666666667
# xG for Brentford with 5 shots on target: 1.8333333333333333
# xG for Brentford with 3 shots on target: 0.95
# xG for Brentford with 3 shots on target: 0.95
# xG for Brentford with 5 shots on target: 1.8333333333333333
# xG for Brentford with 4 shots on target: 1.4166666666666667
# xG for Brentford with 5 shots on target: 1.8333333333333333
# xG for Brentford with 6 shots on target: 2.2142857142857144
# xG for Brentford with 7 shots on target: 3.0
# xG for Brentford with 4 shots on target: 1.4166666666666667
# xG for Brentford with 2 shots on target: 0.4666666666666667
# xG for Brentford with 8 shots on target: 3.6
# xG for Brentford with 2 shots on target: 0.4666666666666667
# xG for Brentford with 3 shots on target: 0.95
# xG for Brentford with 1 shots on target: 0.14285714285714285
# xG for Brentford with 6 shots on target: 2.2142857142857144
# xG for Brentford with 2 shots on target: 0.4666666666666667
# xG for Brentford with 3 shots on target: 0.95
# xG for Brentford with 5 shots on target: 1.8333333333333333
# xG for Brentford with 3 shots on target: 0.95
# xG for Brentford with 3 shots on target: 0.95
# xG for Brentford with 5 shots on target: 1.8333333333333333
# xG for Brentford with 4 shots on target: 1.4166666666666667
# xG for Brentford with 5 shots on target: 1.8333333333333333
# xG for Brentford with 1 shots on target: 0.14285714285714285
# xG for Brentford with 4 shots on target: 1.4166666666666667
# xG for Brentford with 7 shots on target: 3.0
# xG for Brentford with 4 shots on target: 1.4166666666666667
# xG for Fulham with 4 shots on target: 1.173913043478261
# xG for Fulham with 3 shots on target: 0.9166666666666666
# xG for Fulham with 7 shots on target: 3.0
# xG for Fulham with 3 shots on target: 0.9166666666666666
# xG for Fulham with 5 shots on target: 1.5
# xG for Fulham with 3 shots on target: 0.9166666666666666
# xG for Fulham with 3 shots on target: 0.9166666666666666
# xG for Fulham with 7 shots on target: 3.0
# xG for Fulham with 3 shots on target: 0.9166666666666666
# xG for Fulham with 2 shots on target: 0.6875
# xG for Fulham with 4 shots on target: 1.173913043478261
# xG for Fulham with 8 shots on target: 3.0
# xG for Fulham with 7 shots on target: 3.0
# xG for Fulham with 3 shots on target: 0.9166666666666666
# xG for Fulham with 2 shots on target: 0.6875
# xG for Fulham with 5 shots on target: 1.5
# xG for Fulham with 7 shots on target: 3.0
# xG for Fulham with 4 shots on target: 1.173913043478261
# xG for Fulham with 4 shots on target: 1.173913043478261
# xG for Fulham with 2 shots on target: 0.6875
# xG for Fulham with 4 shots on target: 1.173913043478261
# xG for Fulham with 4 shots on target: 1.173913043478261
# xG for Fulham with 5 shots on target: 1.5
# xG for Fulham with 2 shots on target: 0.6875
# xG for Fulham with 4 shots on target: 1.173913043478261
# xG for Fulham with 5 shots on target: 1.5
# xG for Fulham with 2 shots on target: 0.6875
# xG for Fulham with 3 shots on target: 0.9166666666666666
# xG for Fulham with 2 shots on target: 0.6875
# xG for Fulham with 3 shots on target: 0.9166666666666666
# xG for Fulham with 7 shots on target: 3.0
# xG for Fulham with 5 shots on target: 1.5
# xG for Fulham with 0 shots on target: 0.5
# xG for Fulham with 1 shots on target: 0.625
# xG for Fulham with 12 shots on target: 5.0
# xG for Fulham with 4 shots on target: 1.173913043478261
# xG for Fulham with 4 shots on target: 1.173913043478261
# xG for Fulham with 3 shots on target: 0.9166666666666666
# xG for Crystal Palace with 2 shots on target: 0.2857142857142857
# xG for Crystal Palace with 4 shots on target: 1.263157894736842
# xG for Crystal Palace with 8 shots on target: 3.0
# xG for Crystal Palace with 5 shots on target: 1.4666666666666666
# xG for Crystal Palace with 4 shots on target: 1.263157894736842
# xG for Crystal Palace with 2 shots on target: 0.2857142857142857
# xG for Crystal Palace with 5 shots on target: 1.4666666666666666
# xG for Crystal Palace with 2 shots on target: 0.2857142857142857
# xG for Crystal Palace with 3 shots on target: 0.5555555555555556
# xG for Crystal Palace with 5 shots on target: 1.4666666666666666
# xG for Crystal Palace with 1 shots on target: 0.0
# xG for Crystal Palace with 4 shots on target: 1.263157894736842
# xG for Crystal Palace with 2 shots on target: 0.2857142857142857
# xG for Crystal Palace with 3 shots on target: 0.5555555555555556
# xG for Crystal Palace with 6 shots on target: 2.0
# xG for Crystal Palace with 0 shots on target: 0.0
# xG for Crystal Palace with 0 shots on target: 0.0
# xG for Crystal Palace with 5 shots on target: 1.4666666666666666
# xG for Crystal Palace with 3 shots on target: 0.5555555555555556
# xG for Crystal Palace with 2 shots on target: 0.2857142857142857
# xG for Crystal Palace with 1 shots on target: 0.0
# xG for Crystal Palace with 3 shots on target: 0.5555555555555556
# xG for Crystal Palace with 4 shots on target: 1.263157894736842
# xG for Crystal Palace with 4 shots on target: 1.263157894736842
# xG for Crystal Palace with 0 shots on target: 0.0
# xG for Crystal Palace with 0 shots on target: 0.0
# xG for Crystal Palace with 0 shots on target: 0.0
# xG for Crystal Palace with 5 shots on target: 1.4666666666666666
# xG for Crystal Palace with 7 shots on target: 2.75
# xG for Crystal Palace with 12 shots on target: 5.0
# xG for Crystal Palace with 5 shots on target: 1.4666666666666666
# xG for Crystal Palace with 2 shots on target: 0.2857142857142857
# xG for Crystal Palace with 4 shots on target: 1.263157894736842
# xG for Crystal Palace with 7 shots on target: 2.75
# xG for Crystal Palace with 2 shots on target: 0.2857142857142857
# xG for Crystal Palace with 5 shots on target: 1.4666666666666666
# xG for Crystal Palace with 5 shots on target: 1.4666666666666666
# xG for Crystal Palace with 3 shots on target: 0.5555555555555556
# xG for Chelsea with 6 shots on target: 1.5
# xG for Chelsea with 3 shots on target: 0.7727272727272727
# xG for Chelsea with 3 shots on target: 0.7727272727272727
# xG for Chelsea with 4 shots on target: 1.0
# xG for Chelsea with 4 shots on target: 1.0
# xG for Chelsea with 3 shots on target: 0.7727272727272727
# xG for Chelsea with 3 shots on target: 0.7727272727272727
# xG for Chelsea with 3 shots on target: 0.7727272727272727
# xG for Chelsea with 7 shots on target: 2.0
# xG for Chelsea with 4 shots on target: 1.0
# xG for Chelsea with 5 shots on target: 1.3333333333333333
# xG for Chelsea with 2 shots on target: 0.5
# xG for Chelsea with 7 shots on target: 2.0
# xG for Chelsea with 1 shots on target: 0.2222222222222222
# xG for Chelsea with 2 shots on target: 0.5
# xG for Chelsea with 5 shots on target: 1.3333333333333333
# xG for Chelsea with 2 shots on target: 0.5
# xG for Chelsea with 2 shots on target: 0.5
# xG for Chelsea with 10 shots on target: 3.0
# xG for Chelsea with 5 shots on target: 1.3333333333333333
# xG for Chelsea with 2 shots on target: 0.5
# xG for Chelsea with 3 shots on target: 0.7727272727272727
# xG for Chelsea with 4 shots on target: 1.0
# xG for Chelsea with 5 shots on target: 1.3333333333333333
# xG for Chelsea with 2 shots on target: 0.5
# xG for Chelsea with 3 shots on target: 0.7727272727272727
# xG for Chelsea with 6 shots on target: 1.5
# xG for Chelsea with 7 shots on target: 2.0
# xG for Chelsea with 2 shots on target: 0.5
# xG for Chelsea with 1 shots on target: 0.2222222222222222
# xG for Chelsea with 4 shots on target: 1.0
# xG for Chelsea with 5 shots on target: 1.3333333333333333
# xG for Chelsea with 3 shots on target: 0.7727272727272727
# xG for Chelsea with 6 shots on target: 1.5
# xG for Chelsea with 9 shots on target: 3.0
# xG for Chelsea with 4 shots on target: 1.0
# xG for Chelsea with 3 shots on target: 0.7727272727272727
# xG for Chelsea with 5 shots on target: 1.3333333333333333
# xG for Wolverhampton Wanderers with 2 shots on target: 0.1875
# xG for Wolverhampton Wanderers with 5 shots on target: 1.15
# xG for Wolverhampton Wanderers with 2 shots on target: 0.1875
# xG for Wolverhampton Wanderers with 2 shots on target: 0.1875
# xG for Wolverhampton Wanderers with 3 shots on target: 0.5909090909090909
# xG for Wolverhampton Wanderers with 4 shots on target: 0.8260869565217391
# xG for Wolverhampton Wanderers with 5 shots on target: 1.15
# xG for Wolverhampton Wanderers with 5 shots on target: 1.15
# xG for Wolverhampton Wanderers with 4 shots on target: 0.8260869565217391
# xG for Wolverhampton Wanderers with 5 shots on target: 1.15
# xG for Wolverhampton Wanderers with 8 shots on target: 2.5
# xG for Wolverhampton Wanderers with 4 shots on target: 0.8260869565217391
# xG for Wolverhampton Wanderers with 5 shots on target: 1.15
# xG for Wolverhampton Wanderers with 2 shots on target: 0.1875
# xG for Wolverhampton Wanderers with 3 shots on target: 0.5909090909090909
# xG for Wolverhampton Wanderers with 6 shots on target: 1.3
# xG for Wolverhampton Wanderers with 8 shots on target: 2.5
# xG for Wolverhampton Wanderers with 1 shots on target: 0.2
# xG for Wolverhampton Wanderers with 4 shots on target: 0.8260869565217391
# xG for Wolverhampton Wanderers with 1 shots on target: 0.2
# xG for Wolverhampton Wanderers with 3 shots on target: 0.5909090909090909
# xG for Wolverhampton Wanderers with 3 shots on target: 0.5909090909090909
# xG for Wolverhampton Wanderers with 4 shots on target: 0.8260869565217391
# xG for Wolverhampton Wanderers with 2 shots on target: 0.1875
# xG for Wolverhampton Wanderers with 6 shots on target: 1.3
# xG for Wolverhampton Wanderers with 4 shots on target: 0.8260869565217391
# xG for Wolverhampton Wanderers with 3 shots on target: 0.5909090909090909
# xG for Wolverhampton Wanderers with 4 shots on target: 0.8260869565217391
# xG for Wolverhampton Wanderers with 5 shots on target: 1.15
# xG for Wolverhampton Wanderers with 2 shots on target: 0.1875
# xG for Wolverhampton Wanderers with 4 shots on target: 0.8260869565217391
# xG for Wolverhampton Wanderers with 1 shots on target: 0.2
# xG for Wolverhampton Wanderers with 5 shots on target: 1.15
# xG for Wolverhampton Wanderers with 4 shots on target: 0.8260869565217391
# xG for Wolverhampton Wanderers with 4 shots on target: 0.8260869565217391
# xG for Wolverhampton Wanderers with 3 shots on target: 0.5909090909090909
# xG for Wolverhampton Wanderers with 1 shots on target: 0.2
# xG for Wolverhampton Wanderers with 6 shots on target: 1.3
# xG for West Ham United with 3 shots on target: 0.625
# xG for West Ham United with 9 shots on target: 3.3333333333333335
# xG for West Ham United with 2 shots on target: 0.2777777777777778
# xG for West Ham United with 4 shots on target: 1.0
# xG for West Ham United with 6 shots on target: 2.125
# xG for West Ham United with 2 shots on target: 0.2777777777777778
# xG for West Ham United with 10 shots on target: 3.5
# xG for West Ham United with 5 shots on target: 1.4375
# xG for West Ham United with 5 shots on target: 1.4375
# xG for West Ham United with 3 shots on target: 0.625
# xG for West Ham United with 2 shots on target: 0.2777777777777778
# xG for West Ham United with 4 shots on target: 1.0
# xG for West Ham United with 2 shots on target: 0.2777777777777778
# xG for West Ham United with 7 shots on target: 3.0
# xG for West Ham United with 1 shots on target: 0.18181818181818182
# xG for West Ham United with 3 shots on target: 0.625
# xG for West Ham United with 5 shots on target: 1.4375
# xG for West Ham United with 4 shots on target: 1.0
# xG for West Ham United with 2 shots on target: 0.2777777777777778
# xG for West Ham United with 4 shots on target: 1.0
# xG for West Ham United with 5 shots on target: 1.4375
# xG for West Ham United with 3 shots on target: 0.625
# xG for West Ham United with 4 shots on target: 1.0
# xG for West Ham United with 1 shots on target: 0.18181818181818182
# xG for West Ham United with 4 shots on target: 1.0
# xG for West Ham United with 2 shots on target: 0.2777777777777778
# xG for West Ham United with 6 shots on target: 2.125
# xG for West Ham United with 3 shots on target: 0.625
# xG for West Ham United with 4 shots on target: 1.0
# xG for West Ham United with 8 shots on target: 3.3333333333333335
# xG for West Ham United with 5 shots on target: 1.4375
# xG for West Ham United with 3 shots on target: 0.625
# xG for West Ham United with 4 shots on target: 1.0
# xG for West Ham United with 4 shots on target: 1.0
# xG for West Ham United with 2 shots on target: 0.2777777777777778
# xG for West Ham United with 3 shots on target: 0.625
# xG for West Ham United with 2 shots on target: 0.2777777777777778
# xG for West Ham United with 1 shots on target: 0.18181818181818182
# xG for Bournemouth with 2 shots on target: 0.05555555555555555
# xG for Bournemouth with 3 shots on target: 0.35
# xG for Bournemouth with 0 shots on target: 0.0
# xG for Bournemouth with 5 shots on target: 1.3846153846153846
# xG for Bournemouth with 9 shots on target: 3.3333333333333335
# xG for Bournemouth with 4 shots on target: 0.8235294117647058
# xG for Bournemouth with 3 shots on target: 0.35
# xG for Bournemouth with 8 shots on target: 3.0
# xG for Bournemouth with 6 shots on target: 2.0
# xG for Bournemouth with 7 shots on target: 2.375
# xG for Bournemouth with 3 shots on target: 0.35
# xG for Bournemouth with 4 shots on target: 0.8235294117647058
# xG for Bournemouth with 5 shots on target: 1.3846153846153846
# xG for Bournemouth with 3 shots on target: 0.35
# xG for Bournemouth with 4 shots on target: 0.8235294117647058
# xG for Bournemouth with 4 shots on target: 0.8235294117647058
# xG for Bournemouth with 2 shots on target: 0.05555555555555555
# xG for Bournemouth with 4 shots on target: 0.8235294117647058
# xG for Bournemouth with 2 shots on target: 0.05555555555555555
# xG for Bournemouth with 3 shots on target: 0.35
# xG for Bournemouth with 2 shots on target: 0.05555555555555555
# xG for Bournemouth with 2 shots on target: 0.05555555555555555
# xG for Bournemouth with 1 shots on target: 0.0
# xG for Bournemouth with 7 shots on target: 2.375
# xG for Bournemouth with 7 shots on target: 2.375
# xG for Bournemouth with 5 shots on target: 1.3846153846153846
# xG for Bournemouth with 3 shots on target: 0.35
# xG for Bournemouth with 3 shots on target: 0.35
# xG for Bournemouth with 6 shots on target: 2.0
# xG for Bournemouth with 5 shots on target: 1.3846153846153846
# xG for Bournemouth with 1 shots on target: 0.0
# xG for Bournemouth with 4 shots on target: 0.8235294117647058
# xG for Bournemouth with 8 shots on target: 3.0
# xG for Bournemouth with 2 shots on target: 0.05555555555555555
# xG for Bournemouth with 2 shots on target: 0.05555555555555555
# xG for Bournemouth with 1 shots on target: 0.0
# xG for Bournemouth with 1 shots on target: 0.0
# xG for Bournemouth with 6 shots on target: 2.0
# xG for Nottingham Forest with 2 shots on target: 0.3125
# xG for Nottingham Forest with 4 shots on target: 0.85
# xG for Nottingham Forest with 5 shots on target: 1.3333333333333333
# xG for Nottingham Forest with 1 shots on target: 0.0
# xG for Nottingham Forest with 1 shots on target: 0.0
# xG for Nottingham Forest with 6 shots on target: 1.8571428571428572
# xG for Nottingham Forest with 4 shots on target: 0.85
# xG for Nottingham Forest with 6 shots on target: 1.8571428571428572
# xG for Nottingham Forest with 2 shots on target: 0.3125
# xG for Nottingham Forest with 3 shots on target: 0.6
# xG for Nottingham Forest with 2 shots on target: 0.3125
# xG for Nottingham Forest with 1 shots on target: 0.0
# xG for Nottingham Forest with 4 shots on target: 0.85
# xG for Nottingham Forest with 2 shots on target: 0.3125
# xG for Nottingham Forest with 7 shots on target: 2.3333333333333335
# xG for Nottingham Forest with 5 shots on target: 1.3333333333333333
# xG for Nottingham Forest with 3 shots on target: 0.6
# xG for Nottingham Forest with 3 shots on target: 0.6
# xG for Nottingham Forest with 3 shots on target: 0.6
# xG for Nottingham Forest with 6 shots on target: 1.8571428571428572
# xG for Nottingham Forest with 5 shots on target: 1.3333333333333333
# xG for Nottingham Forest with 4 shots on target: 0.85
# xG for Nottingham Forest with 3 shots on target: 0.6
# xG for Nottingham Forest with 4 shots on target: 0.85
# xG for Nottingham Forest with 3 shots on target: 0.6
# xG for Nottingham Forest with 6 shots on target: 1.8571428571428572
# xG for Nottingham Forest with 5 shots on target: 1.3333333333333333
# xG for Nottingham Forest with 3 shots on target: 0.6
# xG for Nottingham Forest with 5 shots on target: 1.3333333333333333
# xG for Nottingham Forest with 2 shots on target: 0.3125
# xG for Nottingham Forest with 0 shots on target: 0.0
# xG for Nottingham Forest with 6 shots on target: 1.8571428571428572
# xG for Nottingham Forest with 7 shots on target: 2.3333333333333335
# xG for Nottingham Forest with 3 shots on target: 0.6
# xG for Nottingham Forest with 7 shots on target: 2.3333333333333335
# xG for Nottingham Forest with 6 shots on target: 1.8571428571428572
# xG for Nottingham Forest with 4 shots on target: 0.85
# xG for Nottingham Forest with 4 shots on target: 0.85
# xG for Everton with 2 shots on target: 0.09090909090909091
# xG for Everton with 4 shots on target: 0.7391304347826086
# xG for Everton with 5 shots on target: 1.0
# xG for Everton with 3 shots on target: 0.5789473684210527
# xG for Everton with 4 shots on target: 0.7391304347826086
# xG for Everton with 3 shots on target: 0.5789473684210527
# xG for Everton with 2 shots on target: 0.09090909090909091
# xG for Everton with 4 shots on target: 0.7391304347826086
# xG for Everton with 6 shots on target: 1.1818181818181819
# xG for Everton with 4 shots on target: 0.7391304347826086
# xG for Everton with 0 shots on target: 0.0
# xG for Everton with 0 shots on target: 0.0
# xG for Everton with 8 shots on target: 2.25
# xG for Everton with 3 shots on target: 0.5789473684210527
# xG for Everton with 1 shots on target: 0.0
# xG for Everton with 3 shots on target: 0.5789473684210527
# xG for Everton with 5 shots on target: 1.0
# xG for Everton with 4 shots on target: 0.7391304347826086
# xG for Everton with 4 shots on target: 0.7391304347826086
# xG for Everton with 4 shots on target: 0.7391304347826086
# xG for Everton with 2 shots on target: 0.09090909090909091
# xG for Everton with 4 shots on target: 0.7391304347826086
# xG for Everton with 1 shots on target: 0.0
# xG for Everton with 5 shots on target: 1.0
# xG for Everton with 3 shots on target: 0.5789473684210527
# xG for Everton with 7 shots on target: 2.0
# xG for Everton with 5 shots on target: 1.0
# xG for Everton with 7 shots on target: 2.0
# xG for Everton with 4 shots on target: 0.7391304347826086
# xG for Everton with 0 shots on target: 0.0
# xG for Everton with 4 shots on target: 0.7391304347826086
# xG for Everton with 5 shots on target: 1.0
# xG for Everton with 5 shots on target: 1.0
# xG for Everton with 8 shots on target: 2.25
# xG for Everton with 10 shots on target: 5.0
# xG for Everton with 3 shots on target: 0.5789473684210527
# xG for Everton with 5 shots on target: 1.0
# xG for Everton with 6 shots on target: 1.1818181818181819
# xG for Leicester with 5 shots on target: 1.375
# xG for Leicester with 4 shots on target: 1.0
# xG for Leicester with 4 shots on target: 1.0
# xG for Leicester with 5 shots on target: 1.375
# xG for Leicester with 2 shots on target: 0.3333333333333333
# xG for Leicester with 4 shots on target: 1.0
# xG for Leicester with 4 shots on target: 1.0
# xG for Leicester with 7 shots on target: 2.3333333333333335
# xG for Leicester with 9 shots on target: 3.1666666666666665
# xG for Leicester with 5 shots on target: 1.375
# xG for Leicester with 3 shots on target: 0.8
# xG for Leicester with 5 shots on target: 1.375
# xG for Leicester with 10 shots on target: 3.75
# xG for Leicester with 3 shots on target: 0.8
# xG for Leicester with 8 shots on target: 2.8333333333333335
# xG for Leicester with 6 shots on target: 2.0
# xG for Leicester with 2 shots on target: 0.3333333333333333
# xG for Leicester with 2 shots on target: 0.3333333333333333
# xG for Leicester with 4 shots on target: 1.0
# xG for Leicester with 1 shots on target: 0.14285714285714285
# xG for Leicester with 4 shots on target: 1.0
# xG for Leicester with 10 shots on target: 3.75
# xG for Leicester with 7 shots on target: 2.3333333333333335
# xG for Leicester with 3 shots on target: 0.8
# xG for Leicester with 0 shots on target: 0.0
# xG for Leicester with 0 shots on target: 0.0
# xG for Leicester with 4 shots on target: 1.0
# xG for Leicester with 3 shots on target: 0.8
# xG for Leicester with 3 shots on target: 0.8
# xG for Leicester with 4 shots on target: 1.0
# xG for Leicester with 4 shots on target: 1.0
# xG for Leicester with 8 shots on target: 2.8333333333333335
# xG for Leicester with 3 shots on target: 0.8
# xG for Leicester with 6 shots on target: 2.0
# xG for Leicester with 9 shots on target: 3.1666666666666665
# xG for Leicester with 3 shots on target: 0.8
# xG for Leicester with 1 shots on target: 0.14285714285714285
# xG for Leicester with 4 shots on target: 1.0
# xG for Leeds United with 4 shots on target: 1.1764705882352942
# xG for Leeds United with 5 shots on target: 1.5789473684210527
# xG for Leeds United with 6 shots on target: 1.7857142857142858
# xG for Leeds United with 2 shots on target: 0.38461538461538464
# xG for Leeds United with 5 shots on target: 1.5789473684210527
# xG for Leeds United with 6 shots on target: 1.7857142857142858
# xG for Leeds United with 6 shots on target: 1.7857142857142858
# xG for Leeds United with 7 shots on target: 2.2
# xG for Leeds United with 1 shots on target: 0.2
# xG for Leeds United with 4 shots on target: 1.1764705882352942
# xG for Leeds United with 3 shots on target: 0.8823529411764706
# xG for Leeds United with 2 shots on target: 0.38461538461538464
# xG for Leeds United with 5 shots on target: 1.5789473684210527
# xG for Leeds United with 6 shots on target: 1.7857142857142858
# xG for Leeds United with 10 shots on target: 4.0
# xG for Leeds United with 7 shots on target: 2.2
# xG for Leeds United with 5 shots on target: 1.5789473684210527
# xG for Leeds United with 1 shots on target: 0.2
# xG for Leeds United with 6 shots on target: 1.7857142857142858
# xG for Leeds United with 4 shots on target: 1.1764705882352942
# xG for Leeds United with 3 shots on target: 0.8823529411764706
# xG for Leeds United with 0 shots on target: 0.0
# xG for Leeds United with 1 shots on target: 0.2
# xG for Leeds United with 0 shots on target: 0.0
# xG for Leeds United with 4 shots on target: 1.1764705882352942
# xG for Leeds United with 2 shots on target: 0.38461538461538464
# xG for Leeds United with 4 shots on target: 1.1764705882352942
# xG for Leeds United with 8 shots on target: 3.0
# xG for Leeds United with 5 shots on target: 1.5789473684210527
# xG for Leeds United with 6 shots on target: 1.7857142857142858
# xG for Leeds United with 3 shots on target: 0.8823529411764706
# xG for Leeds United with 2 shots on target: 0.38461538461538464
# xG for Leeds United with 3 shots on target: 0.8823529411764706
# xG for Leeds United with 6 shots on target: 1.7857142857142858
# xG for Leeds United with 2 shots on target: 0.38461538461538464
# xG for Leeds United with 4 shots on target: 1.1764705882352942
# xG for Leeds United with 3 shots on target: 0.8823529411764706
# xG for Leeds United with 4 shots on target: 1.1764705882352942
# xG for Southampton with 4 shots on target: 1.1
# xG for Southampton with 5 shots on target: 1.5
# xG for Southampton with 6 shots on target: 1.7692307692307692
# xG for Southampton with 2 shots on target: 0.2777777777777778
# xG for Southampton with 6 shots on target: 1.7692307692307692
# xG for Southampton with 1 shots on target: 0.0
# xG for Southampton with 1 shots on target: 0.0
# xG for Southampton with 1 shots on target: 0.0
# xG for Southampton with 4 shots on target: 1.1
# xG for Southampton with 0 shots on target: 0.0
# xG for Southampton with 4 shots on target: 1.1
# xG for Southampton with 3 shots on target: 0.5
# xG for Southampton with 3 shots on target: 0.5
# xG for Southampton with 2 shots on target: 0.2777777777777778
# xG for Southampton with 5 shots on target: 1.5
# xG for Southampton with 5 shots on target: 1.5
# xG for Southampton with 4 shots on target: 1.1
# xG for Southampton with 5 shots on target: 1.5
# xG for Southampton with 0 shots on target: 0.0
# xG for Southampton with 5 shots on target: 1.5
# xG for Southampton with 3 shots on target: 0.5
# xG for Southampton with 2 shots on target: 0.2777777777777778
# xG for Southampton with 3 shots on target: 0.5
# xG for Southampton with 5 shots on target: 1.5
# xG for Southampton with 2 shots on target: 0.2777777777777778
# xG for Southampton with 5 shots on target: 1.5
# xG for Southampton with 3 shots on target: 0.5
# xG for Southampton with 7 shots on target: 2.5
# xG for Southampton with 2 shots on target: 0.2777777777777778
# xG for Southampton with 3 shots on target: 0.5
# xG for Southampton with 1 shots on target: 0.0
# xG for Southampton with 6 shots on target: 1.7692307692307692
# xG for Southampton with 2 shots on target: 0.2777777777777778
# xG for Southampton with 3 shots on target: 0.5
# xG for Southampton with 5 shots on target: 1.5
# xG for Southampton with 2 shots on target: 0.2777777777777778
# xG for Southampton with 5 shots on target: 1.5
# xG for Southampton with 9 shots on target: 4.0

# %% [markdown]
# ### Accuracy Score

# %%
# Calculate accuracy metrics
mae = mean_absolute_error(df['goals'], df['predicted_goals'])
mse = mean_squared_error(df['goals'], df['predicted_goals'])
rmse = np.sqrt(mse)
r2 = r2_score(df['goals'], df['predicted_goals'])

# Print accuracy results
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.4021
# Mean Squared Error (MSE): 0.2680
# Root Mean Squared Error (RMSE): 0.5177
# R² Score: 0.8497

# %% [markdown]
# The algorithm has an accuracy of 84.97% when predicting the number of goals scored by each team. To break it down further, we will compute the R-squared values for each team in the dataset.

# %%
# Get unique teams
teams = df['team_name'].unique()

for i, team in enumerate(teams):
    team_data = df[df['team_name'] == team]
    r2 = r2_score(team_data['goals'], team_data['predicted_goals'])
    print(f"R² Score for {team}: {r2:.4f}")
# Out:
# R² Score for Manchester City: 0.8879
# R² Score for Arsenal: 0.8615
# R² Score for Manchester United: 0.8282
# R² Score for Newcastle United: 0.9221
# R² Score for Liverpool: 0.8799
# R² Score for Brighton & Hove Albion: 0.9077
# R² Score for Aston Villa: 0.6876
# R² Score for Tottenham Hotspur: 0.9003
# R² Score for Brentford: 0.7535
# R² Score for Fulham: 0.7321
# R² Score for Crystal Palace: 0.8450
# R² Score for Chelsea: 0.4880
# R² Score for Wolverhampton Wanderers: 0.5671
# R² Score for West Ham United: 0.8282
# R² Score for Bournemouth: 0.8976
# R² Score for Nottingham Forest: 0.7957
# R² Score for Everton: 0.8700
# R² Score for Leicester: 0.7340
# R² Score for Leeds United: 0.7461
# R² Score for Southampton: 0.7882

# %% [markdown]
# ### Visualizations

# %%
# Plot actual vs predicted goals
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['goals'], y=df['predicted_goals'], alpha=0.7, color='blue')

# Add a diagonal reference line (perfect prediction line)
plt.plot([df['goals'].min(), df['goals'].max()], 
         [df['goals'].min(), df['goals'].max()], 
         linestyle='--', color='red', label="Perfect Prediction")

# Labels and title
plt.xlabel("Actual Goals")
plt.ylabel("Predicted Goals")
plt.title("Predicted Goals vs Actual Goals")
plt.legend()
plt.show()

# %% [markdown]
# The plot for the whole dataset show the sparse nature of the data which is hard to to fitted along the dashed line. Since we are not able to properly visualize the points using the whole dataset, we will plot separate graphs for all 20 Premier League teams in the dataset. The results are shown below:

# %%
# Get unique teams
teams = df['team_name'].unique()
num_teams = len(teams)

# Define grid size (3 columns per row)
cols = 3
rows = int(np.ceil(num_teams / cols))  # Calculate required rows

# Create subplots
fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(5 * cols, 5 * rows), sharey=True)

# Flatten the axes array for easy iteration (handles cases where rows * cols > num_teams)
axes = axes.flatten()

for i, team in enumerate(teams):
    team_data = df[df['team_name'] == team]

    # Scatter plot for each team
    sns.scatterplot(x=team_data['goals'], y=team_data['predicted_goals'], alpha=0.7, ax=axes[i], color='blue')
    
    # Perfect prediction line
    min_goal, max_goal = team_data['goals'].min(), team_data['goals'].max()
    axes[i].plot([min_goal, max_goal], [min_goal, max_goal], linestyle='--', color='red', label="Perfect Prediction")

    # Labels
    axes[i].set_xlabel("Actual Goals")
    axes[i].set_ylabel("Predicted Goals")
    axes[i].set_title(f"Predictions for {team}")
    axes[i].legend()

# Hide unused subplots (if teams don't fill all slots)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# Get unique teams
teams = df['team_name'].unique()
num_teams = len(teams)

# Define grid size (3 columns per row)
cols = 3
rows = int(np.ceil(num_teams / cols))  # Calculate required rows

# Create subplots
fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(5 * cols, 5 * rows), sharey=True)

# Flatten the axes array for easy iteration
axes = axes.flatten()

for i, team in enumerate(teams):
    team_data = df[df['team_name'] == team]

    # Scatter plot for actual goals
    sns.scatterplot(x=team_data['shots_on_target'], y=team_data['goals'], alpha=0.7, ax=axes[i], color='blue', label="Actual Goals")

    # Scatter plot for predicted goals
    sns.scatterplot(x=team_data['shots_on_target'], y=team_data['predicted_goals'], alpha=0.7, ax=axes[i], color='orange', label="Predicted Goals")
    sns.lineplot(x=team_data['shots_on_target'], y=team_data['predicted_goals'], ax=axes[i], color='orange', linestyle='-', marker='o')


    # Labels
    axes[i].set_xlabel("Shots on Target")
    axes[i].set_ylabel("Goals")
    axes[i].set_title(f"Shots vs Goals for {team}")
    axes[i].legend()

# Hide unused subplots (if teams don't fill all slots)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Takeaways

# %% [markdown]
# From this algorithm, we found out that two important features to predict the number of goals are the shots on target and team name. For this particular season, teams like Manchester City, Liverpool, and Arsenal had the highest shot accuracy rate. These teams had higher chances of scoring a goal for every shot on target.
# On the other hand, teams like Everton and Wolverhanpton Wanderers had the lowest shot accuracy in the league. Their lack of finishing resulted in a low number of goals scored, despite having the same number of shots as other teams.

# %% [markdown]
# A custom calcualtion algorithm was used to predict the number of goals scored for every team. This is due to the different shot accuracy rates of the teams in the league, as explored earlier. The algorithm had a strong prediction ability of over 84%, indicating good performance across all teams.
#
# Newcastle United and Brighton & Hove Albion were the teams with the highest R-squared score, where their number of goals could be predicted easily due to consistent performances.
#
# Chelsea and Wolverhampton Wanderers had the lowest R-squared values, signalling less accurate predictions. This variation exists because of the random nature of football. There will be instances when a team can overform or underperform.
